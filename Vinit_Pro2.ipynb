# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("bike.csv")

# %%
df
# Out:
#                State  Avg Daily Distance (km)          Brand        Model  \
# 0          Karnataka                    68.84  Royal Enfield   Hunter 350
# 1          Rajasthan                    23.80          Bajaj  Dominar 400
# 2     Madhya Pradesh                    27.67            KTM     125 Duke
# 3          Karnataka                    62.85       Kawasaki    Ninja 300
# 4     Madhya Pradesh                    10.62         Yamaha        FZ V3
# ...              ...                      ...            ...          ...
# 9995         Gujarat                    67.72           Hero  Passion Pro
# 9996           Delhi                    19.94          Bajaj       CT 100
# 9997     West Bengal                    79.95          Bajaj   Pulsar 150
# 9998  Madhya Pradesh                    16.07          Honda          Dio
# 9999     West Bengal                    51.16  Royal Enfield  Classic 350
#
#       Price (INR)  Year_of_Manufacture  Engine Capacity (cc) Fuel Type  \
# ...

# %%
df.head()
# Out:
#             State  Avg Daily Distance (km)          Brand        Model  \
# 0       Karnataka                    68.84  Royal Enfield   Hunter 350
# 1       Rajasthan                    23.80          Bajaj  Dominar 400
# 2  Madhya Pradesh                    27.67            KTM     125 Duke
# 3       Karnataka                    62.85       Kawasaki    Ninja 300
# 4  Madhya Pradesh                    10.62         Yamaha        FZ V3
#
#    Price (INR)  Year_of_Manufacture  Engine Capacity (cc) Fuel Type  \
# 0       252816                 2021                   672  Electric
# 1       131100                 2020                   769    Hybrid
# 2       201016                 2020                   216    Hybrid
# 3       132482                 2021                   556    Petrol
# 4       231796                 2019                   298    Petrol
#
#    Mileage (km/l) Owner Type  Registration Year Insurance Status Seller Type  \
# ...

# %%
df.tail()
# Out:
#                State  Avg Daily Distance (km)          Brand        Model  \
# 9995         Gujarat                    67.72           Hero  Passion Pro
# 9996           Delhi                    19.94          Bajaj       CT 100
# 9997     West Bengal                    79.95          Bajaj   Pulsar 150
# 9998  Madhya Pradesh                    16.07          Honda          Dio
# 9999     West Bengal                    51.16  Royal Enfield  Classic 350
#
#       Price (INR)  Year_of_Manufacture  Engine Capacity (cc) Fuel Type  \
# 9995        95040                 2024                   297  Electric
# 9996       110369                 2015                   210    Hybrid
# 9997       313806                 2018                   267    Hybrid
# 9998       204068                 2018                   856  Electric
# 9999       323583                 2018                   529    Petrol
#
#       Mileage (km/l) Owner Type  Registration Year Insurance Status  \
# ...

# %%
df.shape
# Out:
# (10000, 15)

# %%
df.info
# Out:
# <bound method DataFrame.info of                State  Avg Daily Distance (km)          Brand        Model  \
# 0          Karnataka                    68.84  Royal Enfield   Hunter 350
# 1          Rajasthan                    23.80          Bajaj  Dominar 400
# 2     Madhya Pradesh                    27.67            KTM     125 Duke
# 3          Karnataka                    62.85       Kawasaki    Ninja 300
# 4     Madhya Pradesh                    10.62         Yamaha        FZ V3
# ...              ...                      ...            ...          ...
# 9995         Gujarat                    67.72           Hero  Passion Pro
# 9996           Delhi                    19.94          Bajaj       CT 100
# 9997     West Bengal                    79.95          Bajaj   Pulsar 150
# 9998  Madhya Pradesh                    16.07          Honda          Dio
# 9999     West Bengal                    51.16  Royal Enfield  Classic 350
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   State                    10000 non-null  object
#  1   Avg Daily Distance (km)  10000 non-null  float64
#  2   Brand                    10000 non-null  object
#  3   Model                    10000 non-null  object
#  4   Price (INR)              10000 non-null  int64
#  5   Year_of_Manufacture      10000 non-null  int64
#  6   Engine Capacity (cc)     10000 non-null  int64
#  7   Fuel Type                10000 non-null  object
#  8   Mileage (km/l)           10000 non-null  float64
#  9   Owner Type               10000 non-null  object
#  10  Registration Year        10000 non-null  int64
#  11  Insurance Status         10000 non-null  object
#  12  Seller Type              10000 non-null  object
#  13  Resale Price (INR)       10000 non-null  float64
# ...

# %%
df.describe()
# Out:
#        Avg Daily Distance (km)    Price (INR)  Year_of_Manufacture  \
# count             10000.000000   10000.000000         10000.000000
# mean                 42.533128  224328.722400          2019.510500
# std                  21.676985  100753.660447             2.907668
# min                   5.010000   50031.000000          2015.000000
# 25%                  23.907500  137900.250000          2017.000000
# 50%                  42.480000  223878.000000          2019.000000
# 75%                  61.352500  311464.250000          2022.000000
# max                  80.000000  399981.000000          2024.000000
#
#        Engine Capacity (cc)  Mileage (km/l)  Registration Year  \
# count          10000.000000    10000.000000        10000.00000
# mean             552.695300       67.188926         2020.96510
# std              261.176292       20.891728            2.74897
# min              100.000000       25.000000         2015.00000
# ...

# %%
df.Year_of_Manufacture.hist()
# Out:
# <Axes: >

# %%
sns.boxplot(df.Year_of_Manufacture)
# Out:
# <Axes: ylabel='Year_of_Manufacture'>

# %%
df=df[['Price (INR)','Year_of_Manufacture','Brand','Registration Year','Fuel Type','City Tier','State']]

# %%
df
# Out:
#       Price (INR)  Year_of_Manufacture          Brand  Registration Year  \
# 0          252816                 2021  Royal Enfield               2024
# 1          131100                 2020          Bajaj               2023
# 2          201016                 2020            KTM               2023
# 3          132482                 2021       Kawasaki               2021
# 4          231796                 2019         Yamaha               2019
# ...           ...                  ...            ...                ...
# 9995        95040                 2024           Hero               2024
# 9996       110369                 2015          Bajaj               2020
# 9997       313806                 2018          Bajaj               2018
# 9998       204068                 2018          Honda               2021
# 9999       323583                 2018  Royal Enfield               2018
#
#      Fuel Type City Tier           State
# 0     Electric    Tier 3       Karnataka
# ...

# %%
df.shape
# Out:
# (10000, 7)

# %%
df.isna().sum()
# Out:
# Price (INR)            0
# Year_of_Manufacture    0
# Brand                  0
# Registration Year      0
# Fuel Type              0
# City Tier              0
# State                  0
# dtype: int64

# %%
df.isin([0]).sum()
# Out:
# Price (INR)            0
# Year_of_Manufacture    0
# Brand                  0
# Registration Year      0
# Fuel Type              0
# City Tier              0
# State                  0
# dtype: int64

# %%
df.groupby("Brand").sum()
# Out:
#                Price (INR)  Year_of_Manufacture  Registration Year  \
# Brand
# Bajaj            278410276              2437533            2439180
# Hero             280015545              2502172            2504143
# Honda            269934723              2465700            2467558
# KTM              283163122              2568867            2570686
# Kawasaki         288102918              2607356            2609170
# Royal Enfield    279276348              2530406            2532265
# TVS              274526634              2492043            2493794
# Yamaha           289857658              2591028            2592855
#
#                                                        Fuel Type  \
# Brand
# Bajaj          HybridElectricPetrolElectricElectricHybridHybr...
# Hero           ElectricHybridElectricPetrolElectricHybridHybr...
# Honda          HybridHybridPetrolPetrolPetrolHybridElectricPe...
# KTM            HybridElectricHybridHybridHybridHybridElectric...
# ...

# %%
df.groupby("Brand").count()
# Out:
#                Price (INR)  Year_of_Manufacture  Registration Year  Fuel Type  \
# Brand
# Bajaj                 1207                 1207               1207       1207
# Hero                  1239                 1239               1239       1239
# Honda                 1221                 1221               1221       1221
# KTM                   1272                 1272               1272       1272
# Kawasaki              1291                 1291               1291       1291
# Royal Enfield         1253                 1253               1253       1253
# TVS                   1234                 1234               1234       1234
# Yamaha                1283                 1283               1283       1283
#
#                City Tier  State
# Brand
# Bajaj               1207   1207
# Hero                1239   1239
# Honda               1221   1221
# KTM                 1272   1272
# Kawasaki            1291   1291
# Royal Enfield       1253   1253
# ...

# %%
df.head()
# Out:
#    Price (INR)  Year_of_Manufacture          Brand  Registration Year  \
# 0       252816                 2021  Royal Enfield               2024
# 1       131100                 2020          Bajaj               2023
# 2       201016                 2020            KTM               2023
# 3       132482                 2021       Kawasaki               2021
# 4       231796                 2019         Yamaha               2019
#
#   Fuel Type City Tier           State
# 0  Electric    Tier 3       Karnataka
# 1    Hybrid    Tier 3       Rajasthan
# 2    Hybrid    Tier 3  Madhya Pradesh
# 3    Petrol    Tier 1       Karnataka
# 4    Petrol    Tier 3  Madhya Pradesh

# %%
R = df.pivot_table(index="Year_of_Manufacture", columns="Brand", values="Price (INR)")

# %%
R
# Out:
# Brand                        Bajaj           Hero          Honda  \
# Year_of_Manufacture
# 2015                 240596.835821  228825.776978  221724.333333
# 2016                 230322.254545  228379.669291  223201.777778
# 2017                 239847.206612  223582.216216  212471.786325
# 2018                 235610.180328  237352.805556  232604.747967
# 2019                 237264.448276  224021.259843  231916.201550
# 2020                 221109.550388  209731.560345  212484.794872
# 2021                 229390.066038  227949.935484  215412.504673
# 2022                 229337.703390  225749.569343  210565.178862
# 2023                 221715.891667  222825.984252  220893.563492
# 2024                 221679.290076  231551.796748  227576.573913
#
# Brand                          KTM       Kawasaki  Royal Enfield  \
# Year_of_Manufacture
# 2015                 204565.275000  235033.496403  214861.000000
# 2016                 222429.692857  213830.235849  218789.280303
# ...

# %%
R.count()
# Out:
# Brand
# Bajaj            10
# Hero             10
# Honda            10
# KTM              10
# Kawasaki         10
# Royal Enfield    10
# TVS              10
# Yamaha           10
# dtype: int64

# %%
R.fillna(0,inplace=True)

# %%
R.head()
# Out:
# Brand                        Bajaj           Hero          Honda  \
# Year_of_Manufacture
# 2015                 240596.835821  228825.776978  221724.333333
# 2016                 230322.254545  228379.669291  223201.777778
# 2017                 239847.206612  223582.216216  212471.786325
# 2018                 235610.180328  237352.805556  232604.747967
# 2019                 237264.448276  224021.259843  231916.201550
#
# Brand                          KTM       Kawasaki  Royal Enfield  \
# Year_of_Manufacture
# 2015                 204565.275000  235033.496403  214861.000000
# 2016                 222429.692857  213830.235849  218789.280303
# 2017                 214025.536000  215742.220472  240136.049587
# 2018                 229418.136364  222198.042735  228838.385246
# 2019                 217392.285714  237865.056000  219977.903509
#
# Brand                          TVS         Yamaha
# Year_of_Manufacture
# 2015                 223987.948148  224574.909774
# ...

# %%
R.isna().sum()
# Out:
# Brand
# Bajaj            0
# Hero             0
# Honda            0
# KTM              0
# Kawasaki         0
# Royal Enfield    0
# TVS              0
# Yamaha           0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(R.index,R["KTM"])

# %%
plt.figure(figsize=(16,10))
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.plot(R.index,R["KTM"])

# %%
plt.figure(figsize=(16,10))
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Price",fontsize = 14)
plt.xlabel("Year",fontsize = 14)
plt.ylim(205000,260000)

plt.plot(R.index,R["KTM"])
plt.plot(R.index,R["Bajaj"])

# %%
plt.figure(figsize=(16,10))
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("car",fontsize = 14)
plt.xlabel("year",fontsize = 14)
plt.ylim(185000,260000)
for column in R.columns:
    plt.plot(R.index,R[column],label=column,linewidth=3)
plt.legend(fontsize = 16)
plt.show()
